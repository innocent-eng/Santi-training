# %% [markdown]
# # 💻 Computer Basics Training App
#
# This notebook runs a comprehensive Computer Training Application with:
# - ✅ User Authentication (Login/Signup)
# - 👨‍💼 Admin Content Management
# - 📚 5 Training Categories
# - 📝 Quiz System with Progress Tracking
# - 💾 Import/Export Functionality
# - 🎯 Complete Progress Tracking
#
# ---
#
# ## Quick Start
#
# **Default Admin Login:**
# - Username: `admin`
# - Password: `admin123`
#
# **Or create your own account with admin privileges!**
#
# ---

# %% [markdown]
# ## Step 1: Upload the HTML File
#
# Click the folder icon on the left sidebar, then upload `computer_training_app.html`
#
# **OR** run the cell below if you have the file hosted online:

# %%
# Option A: Download from a URL (if hosted)
# import urllib.request
# url = "https://your-hosting-url.com/computer_training_app.html"
# urllib.request.urlretrieve(url, "computer_training_app.html")
# print("✅ File downloaded successfully!")

# Option B: Manual upload
print("👈 Please upload 'computer_training_app.html' using the file browser on the left")
print("Then run the next cell!")

# %% [markdown]
# ## Step 2: Run the Training App
#
# Execute the cell below to launch the application!

# %%
from IPython.display import HTML, display
import os

# Check if file exists
if not os.path.exists('computer_training_app.html'):
    print("❌ Error: computer_training_app.html not found!")
    print("Please upload the file using the file browser on the left.")
else:
    # Read the HTML file
    with open('computer_training_app.html', 'r', encoding='utf-8') as f:
        html_content = f.read()
    
    # Display the app
    print("🚀 Launching Computer Training App...")
    print("\n📌 Default Admin Login:")
    print("   Username: admin")
    print("   Password: admin123")
    print("\n✨ Scroll down to see the application!\n")
    
    display(HTML(html_content))

# %% [markdown]
# ## 📖 User Guide
#
# ### For Administrators:
#
# 1. **Login** with admin credentials
# 2. **Add Lessons:**
#    - Click the green "➕ Add New Lesson" button
#    - Fill in title, content, and optional media URLs
#    - Add quizzes if desired
# 3. **Edit Lessons:** Click the ✏️ icon
# 4. **Delete Lessons:** Click the 🗑️ icon
#
# ### For Users:
#
# 1. **Create an account** or use existing credentials
# 2. **Select a category** from the sidebar
# 3. **Complete lessons** and mark them as done
# 4. **Take quizzes** to test your knowledge
# 5. **Track progress** with the progress bars
#
# ### Features:
#
# - 📊 **Progress Tracking**: Visual progress bars for each category
# - 📝 **Quiz System**: Take quizzes and earn badges
# - 💾 **Export/Import**: Backup your data anytime
# - 🎯 **Completion Tracking**: See which lessons you've finished
# - 🏆 **Achievement Badges**: Get rewarded for passing quizzes
#
# ---

# %% [markdown]
# ## 🎥 Adding Media Content
#
# ### Images:
# 1. Upload to Google Drive, Imgur, or Dropbox
# 2. Get the direct/shareable link
# 3. Paste in the Image URL field
#
# ### Videos (YouTube):
# 1. Go to your YouTube video
# 2. Click "Share" → "Embed"
# 3. Copy the URL: `https://www.youtube.com/embed/VIDEO_ID`
# 4. Paste in the Video URL field
#
# ### Example YouTube Embed URL:
# ```
# https://www.youtube.com/embed/dQw4w9WgXcQ
# ```
#
# ---

# %% [markdown]
# ## 💾 Backup Your Data
#
# **Important:** All data is stored in your browser's localStorage.
#
# To backup:
# 1. Click the "💾 Export" button in the app
# 2. Save the downloaded JSON file
# 3. Keep it safe!
#
# To restore:
# 1. Click the "📤 Import" button
# 2. Select your saved JSON file
# 3. All data will be restored
#
# ---

# %% [markdown]
# ## 🔧 Troubleshooting
#
# ### App Not Loading?
# - Make sure you uploaded the HTML file
# - Re-run the launch cell
# - Check your browser console for errors
#
# ### Images Not Showing?
# - Verify the URL is accessible
# - Make sure it's a direct image link
# - Try a different hosting service
#
# ### Videos Not Playing?
# - Use YouTube embed format: `/embed/VIDEO_ID`
# - Make sure the video is public
# - Test the URL in a new browser tab
#
# ### Data Not Saving?
# - Check if localStorage is enabled
# - Export data as backup regularly
# - Try clearing browser cache
#
# ---

# %% [markdown]
# ## 🎯 Sample Content Categories
#
# ### Computer Basics:
# - Introduction to Computers
# - Hardware Components
# - Operating Systems
# - File Management
# - Internet Safety
#
# ### Windows Shortcuts:
# - Essential Keyboard Shortcuts
# - Window Management
# - File Explorer Tips
# - Screenshot Techniques
# - Task Manager Tricks
#
# ### MS Word:
# - Document Formatting
# - Styles and Templates
# - Tables and Lists
# - Headers and Footers
# - Track Changes
#
# ### Excel:
# - Basic Formulas
# - Cell Formatting
# - Charts and Graphs
# - PivotTables
# - Data Validation
#
# ### PowerPoint:
# - Slide Design
# - Animations
# - Master Slides
# - Presenter View
# - Export Options
#
# ---

# %% [markdown]
# ## 📞 Support
#
# If you encounter any issues:
# 1. Check the Troubleshooting section above
# 2. Review the README.md file for detailed instructions
# 3. Export your data before making major changes
# 4. Test in a different browser if problems persist
#
# ---
#
# ## 🎉 Enjoy Your Training!
#
# This comprehensive training platform provides everything you need to:
# - ✅ Manage educational content
# - 📚 Learn computer skills
# - 📝 Test knowledge with quizzes
# - 📊 Track learning progress
#
# **Happy Learning!** 🚀
#
# ---
#
# **Version:** 1.0.0
# **Last Updated:** January 2026
# **Developed for:** Google Colab & Web Browsers
